# %%
# %matplotlib inline
from yoga.patient import patient
from yoga.patient import exercise
from yoga.output import fileio
from yoga.output import plot
pat1=patient.Patient("rroy","pass","Mr.","Rajeev","","Roy")
pat1.addRev(100)
pat2=patient.Patient("mzardadi", "pass", "Mr.", "Mohsen", "","Zardadi")
pat2.addRev(200)
ex1=exercise.Exercise("Surya Namaskar", 30)
ex2=exercise.Exercise("Savasana", 10)
fileio.ExportUsers.pcsv(patient.Patient._registery,"patients.csv")
fileio.ExportUsers.ecsv(exercise.Exercise._registery,"exercises.csv")
plot.Plot.revenue(patient.Patient._registery)
plot.Plot.exercise(exercise.Exercise._registery)
